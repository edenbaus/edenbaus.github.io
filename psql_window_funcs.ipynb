# %%
import psycopg2
import pandas as pd
import numpy as np

from plotly.offline import init_notebook_mode, plot, iplot
from plotly.graph_objs import *
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
hostname = '10.0.0.49'
username = 'scott'
password = 'diggler'
database = 'twitch'

# %%
def getQuery(query):
    c = psycopg2.connect( host=hostname, user=username, password=password, dbname=database )
    cur = c.cursor()
    cur.execute(query)
    return list(cur.fetchall())

# %% [markdown]
# # Find most popular game for each batch

# %%
# %%time
query = """
SELECT s.batch AS batch,
       s.game AS game,
       v.max_views AS max_views
  FROM scrape AS s
JOIN
   (SELECT batch, 
           MAX(views) AS max_views
      FROM scrape
  GROUP BY batch
  ORDER BY batch) AS v
ON s.batch = v.batch AND
   s.views = v.max_views
"""

df = getQuery(query)
df = pd.DataFrame(df,columns=['date','game','views'])
# Out:
# CPU times: user 10.3 ms, sys: 3.87 ms, total: 14.1 ms
# Wall time: 12.4 s

# %%
# %%time
query="""
SELECT
    batch,
    first_game AS game,
    first_view AS views
FROM
    (SELECT
        batch,
        FIRST_VALUE(game) OVER (PARTITION BY batch ORDER BY views DESC) AS first_game,
        FIRST_VALUE(views) OVER (PARTITION BY batch ORDER BY views DESC) AS first_view
    FROM
        scrape
    GROUP BY
        batch,
        views,
        game) AS t
GROUP BY
    1,2,3
    ORDER BY batch DESC;
"""
df2 = getQuery(query)

df2 = pd.DataFrame(df2,
                  columns=['date','game','views'])
# Out:
# CPU times: user 7.6 ms, sys: 3.81 ms, total: 11.4 ms
# Wall time: 55 s

# %%
df2 = df2.sort_values('date').reset_index(drop=True)

df = df.sort_values('date').reset_index(drop=True)

colors2 ="#5F9EA0 #4682B4 #B0C4DE #ADD8E6 #B0E0E6 #87CEFA #87CEEB #6495ED #00BFFF #1E90FF #4169E1 #0000FF #0000CD #00008B #000080 #191970 #FFF8DC #FFEBCD #FFE4C4 #FFDEAD #F5DEB3 #DEB887 #D2B48C #BC8F8F #F4A460 #DAA520 #B8860B #CD853F #D2691E #808000 #8B4513 #A0522D #A52A2A #800000".split()
gamedict = dict(zip(df.game.unique(),colors2[::2]))
gameshape = dict(zip(df.game.unique(),[101,102,106,107,108,116,118,119,320,121,321,135,143,110]))

# %%
iplot(
        {
    
            'data':[
                {'type':'scatter',
                'x':df['date'],
                'y':df['views'],
                'opacity':.7,
                 
                 'mode':'markers+lines',
                'marker':{'symbol':df['game'].map(lambda game: gameshape[game]),
                          'size':20,
                          'line':{'width':.2,
                                'color':'#17202A'},
                                  'color':df['game'].map(lambda game: gamedict[game])}}
            ]
    }
)
# Out:
# <div id="51fa1fd7-8f93-4b9d-9ecb-b088b67bdae5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("51fa1fd7-8f93-4b9d-9ecb-b088b67bdae5", [{"opacity": 0.7, "uid": "ee0a3063-b355-4932-b378-799acdd32a8f", "marker": {"color": ["#5F9EA0", "#5F9EA0", "#B0C4DE", "#B0C4DE", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#B0E0E6", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#00BFFF", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9 ...

# %%
dg = df.groupby('game').sum()['views']
iplot(
        {
    
            'data':[
                {'type':'scatter',
                'x':dg.index,
                'y':dg,
                'opacity':.7,
                 'text':dg.index,
                 'mode':'markers+text',
                'marker':{'symbol':19,
                          'opacity':1,
                          'size':dg/1E6,
                          'line':{'width':.2,
                                'color':'#17202A'},
                                  'color':df['game'].map(lambda game: gamedict[game])}}
            ]
    }
)
# Out:
# <div id="f1e6757a-3803-4154-89eb-7e5398019f48" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f1e6757a-3803-4154-89eb-7e5398019f48", [{"opacity": 0.7, "uid": "0d617599-9bfa-4a26-81c6-3883a63193cf", "text": ["Counter-Strike: Global Offensive", "Dota 2", "E3", "E3 2018", "Fortnite", "IRL", "Jurassic World Evolution", "League of Legends", "Ninja Gaiden Black", "Overwatch", "Realm Royale", "Resident Evil 4", "Rocket League", "Super Smash Bros. Melee"], "y": [930557, 35218831, 2454666, 67705598, 178555494, 2903913, 134398, 55531265, 132663, 2212231, 6391556, 156414, 336934, 116860], "mode": "markers+text", "marker": {"color": ["#5F9EA0", "#5F9EA0", "#B0C4DE", "#B0C4DE", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#B0E0E6", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#00BFFF", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#87CEEB", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#4169E1", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#00BFFF", "#00BFFF", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#00BFFF", "#5F9EA0", "#00BFFF", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", "#5F9EA0", " ...

# %%
dd = df.set_index('date')

# %%
DD = dd.to_period('D').groupby('game').max()

# %%
DD.head()
# Out:
#                                     views
# game
# Counter-Strike: Global Offensive   254815
# Dota 2                             356483
# E3                                 563303
# E3 2018                           1785348
# Fortnite                          1468529

# %%
gdict = dict(zip(DD.index,list(range(35))[::-1]))
             
iplot(
        {
    
            'data':[
                {'type':'scatter',
                'x':DD.index,
                'y':DD.views,
                'opacity':.7,
                 'text':DD.index,
                 'mode':'markers+text',
                'marker':{'symbol':DD.index.map(lambda game: gdict[game]),
                          'opacity':1,
                          'size':DD.views/1E4,
                          'line':{'width':.2,
                                'color':'#17202A'},
                                  'color':DD.index.map(lambda game: gamedict[game])}}
            ]
    }
)
# Out:
# <div id="bcca59e9-ed83-4f6f-847a-a4cf77518f7d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bcca59e9-ed83-4f6f-847a-a4cf77518f7d", [{"opacity": 0.7, "uid": "e3fd47d8-6c11-4ed6-ad37-a44e5ba2cd6b", "text": ["Counter-Strike: Global Offensive", "Dota 2", "E3", "E3 2018", "Fortnite", "IRL", "Jurassic World Evolution", "League of Legends", "Ninja Gaiden Black", "Overwatch", "Realm Royale", "Resident Evil 4", "Rocket League", "Super Smash Bros. Melee"], "y": [254815, 356483, 563303, 1785348, 1468529, 179751, 134398, 244273, 132663, 221349, 186000, 156414, 173240, 116860], "mode": "markers+text", "marker": {"color": ["#B0C4DE", "#87CEEB", "#000080", "#FFF8DC", "#5F9EA0", "#FFE4C4", "#D2B48C", "#00BFFF", "#B8860B", "#0000CD", "#4169E1", "#F4A460", "#F5DEB3", "#B0E0E6"], "opacity": 1, "line": {"color": "#17202A", "width": 0.2}, "symbol": [34, 33, 32, 31, 30, 29, 28, 27, 26, 25, 24, 23, 22, 21], "size": [25.4815, 35.6483, 56.3303, 178.5348, 146.8529, 17.9751, 13.4398, 24.4273, 13.2663, 22.1349, 18.6, 15.6414, 17.324, 11.686]}, "x": ["Counter-Strike: Global Offensive", "Dota 2", "E3", "E3 2018", "Fortnite", "IRL", "Jurassic World Evolution", "League of Legends", "Ninja Gaiden Black", "Overwatch", "Realm Royale", "Resident Evil 4", "Rocket League", "Super Smash Bros. Melee"], "type": "scatter"}], {}, {"linkText": "Export to plot.ly", "showLink": true})});</script><script type="text/javascript">window.addEventListener("resize", function(){Plotly.Plots.resize(document.getElementById("bcca59e9-ed83-4f6f-847a-a4cf77518f7d"));});</script>

# %%
## day/day change for dota 2

# %%
query = """
SELECT game,
       EXTRACT(DAY FROM batch) AS day,
       EXTRACT(HOUR FROM batch) AS hour,
       views
FROM scrape
WHERE game = 'Dota 2'
LIMIT 100"""

df = pd.DataFrame(getQuery(query),columns=['game','day','hour','views'])

# %%
query = """
SELECT DATE(batch) AS day,
       COUNT(*) AS Frequency
       FROM scrape
       GROUP BY 1
       ORDER BY 1"""
pd.DataFrame(getQuery(query),columns=['day','Frequency'])
# Out:
#            day  Frequency
# 0   2018-06-03       9686
# 1   2018-06-04      34869
# 2   2018-06-05      68604
# 3   2018-06-06      56502
# 4   2018-06-07     114864
# 5   2018-06-08     115226
# 6   2018-06-09     110468
# 7   2018-06-10     113409
# 8   2018-06-11     119991
# 9   2018-06-12     117126
# 10  2018-06-13     111616
# 11  2018-06-14     108619
# 12  2018-06-15     109115
# 13  2018-06-16     107966
# 14  2018-06-17     108972
# 15  2018-06-18     110081
# 16  2018-06-19     110725
# 17  2018-06-20     109045
# 18  2018-06-21     109151
# 19  2018-06-22     107031
# 20  2018-06-23     102209
# 21  2018-06-24     102730
# 22  2018-06-25      36723

# %%
df.day.value_counts()
# Out:
# 22.0    72
# 20.0    28
# Name: day, dtype: int64

# %%
iplot({
    'data':[
        {'type':' bar',
        'x':df2['date'],
        'y':df2['views']}
    ]})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9d9045e5b221> in <module>()
#       3         {'type':' bar',
#       4         'x':df2['date'],
# ----> 5         'y':df2['views']}
#       6     ]})
#
# /Users/scott/.local/lib/python2.7/site-packages/plotly/offline/offline.pyc in iplot(figure_or_data, show_link, link_text, validate, image, filename, image_width, image_height, config)
#     427     config.setdefault('linkText', link_text)
#     428
# --> 429     figure = tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     430
#     431     # Though it can add quite a bit to the display-bundle size, we include
#
# /Users/scott/.local/lib/python2.7/site-packages/plotly/tools.pyc in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#    1506
#    1507         try:
# -> 1508             figure = Figure(**figure).to_dict()
#    1509         except exceptions.PlotlyError as err:
#    1510             raise exceptions.PlotlyError("Invalid 'figure_or_data' argument. "
#
# /Users/scott/.local/lib/python2.7/site-packages/plotly/graph_objs/_figure.pyc in __init__(self, data, layout, frames, skip_invalid)
#     409             is invalid AND skip_invalid is False
#     410         """
# --> 411         super(Figure, self).__init__(data, layout, frames, skip_invalid)
#     412
#     413     def add_area(
#
# /Users/scott/.local/lib/python2.7/site-packages/plotly/basedatatypes.pyc in __init__(self, data, layout_plotly, frames, skip_invalid)
#     138         # ### Import traces ###
#     139         data = self._data_validator.validate_coerce(data,
# --> 140                                                     skip_invalid=skip_invalid)
#     141
#     142         # ### Save tuple of trace objects ###
#
# /Users/scott/.local/lib/python2.7/site-packages/_plotly_utils/basevalidators.pyc in validate_coerce(self, v, skip_invalid)
#    2295
#    2296             if invalid_els:
# -> 2297                 self.raise_invalid_elements(invalid_els)
#    2298
#    2299             v = to_scalar_or_list(res)
#
# /Users/scott/.local/lib/python2.7/site-packages/_plotly_utils/basevalidators.pyc in raise_invalid_elements(self, invalid_els)
#     264                 pname=self.parent_name,
#     265                 invalid=invalid_els[:10],
# --> 266                 valid_clr_desc=self.description()))
#     267
#     268     def validate_coerce(self, v):
#
# ValueError:
#     Invalid element(s) received for the 'data' property of
#         Invalid elements include: